# %%
import pandas as pd
import re
dataset = pd.read_csv('FlipkartCleanData.csv')
dataset.head()
# Out:
#                                      Name  SalesPrice OriginalPrice Rating  \
# 0        REDMI 9i (Midnight Black, 64 GB)        8299          9999    4.3
# 1      Infinix Hot 10 (Ocean Wave, 64 GB)        8999         11999    4.4
# 2  Infinix Hot 10 (Moonlight Jade, 64 GB)        8999         11999    4.4
# 3               I Kall K400 (Blue, 64 GB)        6299          6499      3
# 4       Infinix Hot 10 (Amber Red, 64 GB)        8999         11999    4.4
#
#                                          ProductLink  \
# 0  https://www.flipkart.com/redmi-9i-midnight-bla...
# 1  https://www.flipkart.com/infinix-hot-10-ocean-...
# 2  https://www.flipkart.com/infinix-hot-10-moonli...
# 3  https://www.flipkart.com/kall-k400-blue-64-gb/...
# 4  https://www.flipkart.com/infinix-hot-10-amber-...
#
#                                            ImageLink
# 0  https://rukminim1.flixcart.com/image/312/312/k...
# 1  https://rukminim1.flixcart.com/image/312/312/k...
# 2  https://rukminim1.flixcart.com/image/312/312/k...
# 3  https://rukminim1.flixcart.com/image/312/312/k...
# 4  https://rukminim1.flixcart.com/image/312/312/k...

# %%
first_synonym = []
second_synonym = []
third_synonym = []

# iterate product name
for mystring in dataset['Name']:

    first_partitioned_string = mystring.rpartition('(')
    first_name = first_partitioned_string[0]
    first_synonym.append(first_name.strip())

    second_partitioned_string = mystring.rpartition(',')
    second_name = second_partitioned_string[0]
    second_synonym.append(second_name.strip())

    third_name = re.sub("[(].*[,]", "", mystring)
    third_synonym.append(third_name.strip())
    
    
# Create dataframe 
df = pd.DataFrame({'first_synonym': first_synonym,
                   'second_synonym': second_synonym,
                  'third_synonym': third_synonym})

# %%
df['second_synonym'] = df['second_synonym'].str.replace(r"[(]",'')
# Out:
# <ipython-input-46-53882f6df33a>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second_synonym'] = df['second_synonym'].str.replace(r"[(]",'')

# %%
df['third_synonym'] = df['third_synonym'].str.replace(r"[)]",'')
# Out:
# <ipython-input-47-bd87a1eae1eb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['third_synonym'] = df['third_synonym'].str.replace(r"[)]",'')

# %%
# Merage all dataframe
df['Synonym'] = df[['first_synonym', 'second_synonym','third_synonym']].apply(lambda x: ' | '.join(x), axis=1)

# create a single list
synonym = df['Synonym'].to_list()

# %%
# insert synonym list in dataframe
dataset.insert(1, "Synonyms",synonym, True)
dataset
# Out:
#                                         Name  \
# 0           REDMI 9i (Midnight Black, 64 GB)
# 1         Infinix Hot 10 (Ocean Wave, 64 GB)
# 2     Infinix Hot 10 (Moonlight Jade, 64 GB)
